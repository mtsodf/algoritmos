# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("execucoes.txt", sep=";")
df["tipo"] = df["file"].apply(lambda x: x.split("/")[-1].split("_")[0])
df["tipo"] = df.tipo.apply(lambda x: "caixeiro" if x == "polygon" else x)
df
# Out:
#                                   file   size   time(s)      tipo
# 0       ../data/regular/regular_10.txt     11  0.000031   regular
# 1      ../data/regular/regular_100.txt    101  0.000835   regular
# 2     ../data/regular/regular_1000.txt   1001  0.061354   regular
# 3    ../data/regular/regular_10000.txt  10001  2.403541   regular
# 4       ../data/regular/regular_10.txt     11  0.000009   regular
# ..                                 ...    ...       ...       ...
# 140   ../data/caxeiro/polygon_50_5.txt     51  0.000237  caixeiro
# 141   ../data/caxeiro/polygon_50_6.txt     51  0.000247  caixeiro
# 142   ../data/caxeiro/polygon_50_7.txt     51  0.000253  caixeiro
# 143   ../data/caxeiro/polygon_50_8.txt     51  0.000262  caixeiro
# 144   ../data/caxeiro/polygon_50_9.txt     51  0.000239  caixeiro
#
# [145 rows x 4 columns]

# %%
fig, ax= plt.subplots()
sns.lineplot(data=df, x="size", y="time(s)", hue="tipo", ax=ax)
ax.plot([10, 100], [1e-3, 1e-1], color="black", ls="--", label="Linear", marker="o")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel("Tamanho Polígono")
ax.set_ylabel("Tempo de Execução (s)")
plt.savefig("../tex/figures/performance.png")
plt.show()

# %%
df.size
# Out:
# 580
